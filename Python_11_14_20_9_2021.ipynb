# %% [markdown]
# <a href="https://colab.research.google.com/github/valenja9/Python_11_14_2021/blob/main/Python_11_14_20_9_2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prvni hodina Pythonu

# %% [markdown]
# ![Python_cheat_sheet.jpg](data:image/jpeg;base64,...)

# %%
#Takle delam komentare

#Jak vypada string v Pythonu
jmeno = "Petr Karel" #uloz do promenne jmeno 
print(jmeno) #vypis(vytiskni) co je uvnitr promenne jmeno
# Out:
# Petr Karel

# %%
jmeno = input("Zadej jmeno: ") # zadavam z klavesnice
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     618         """
# --> 619         parts = [self.recv(flags, copy=copy, track=track)]
#     620         # have first part already, only loop while more to receive
#
# ...

# %%
jmeno = input("Zadej jmeno: ") # zadavam z klavesnice
prijmeni = input("Zadej prijmeni: ") 
vek = int(input("Zadej vek: "))
oblibeny_sport = "Florbal"
print("Tvoje jmeno je:", jmeno ,"Tvoje prijmeni je:", prijmeni, "Tohle je tvuj vek:", vek) #vypis(vytiskni) co je uvnitr promenne jmeno
print("Tvoje jmeno je: " + jmeno + " Tvoje prijmeni je: " + prijmeni + "Tvuj vek je: " + str(vek)) #Vyuzivam vlastnost textu
# Out:
# Zadej jmeno: Jakub
# Zadej prijmeni: Valenta
# Zadej vek: 27
# Tvoje jmeno je: Jakub Tvoje prijmeni je: Valenta Tohle je tvuj vek: 27
# Tvoje jmeno je: Jakub Tvoje prijmeni je: ValentaTvuj vek je: 27

# %%
print(type(vek), type(jmeno))
# Out:
# <class 'int'> <class 'str'>

# %% [markdown]
# Vytvor 3 promenne (veta1 .... veta3).
# Do kazde pomoci inputu uloz text. Text spoj do jedne promenne "vysledny_text" pak ji vypis pomoci printu.

# %%
oddelovac = "=" * 100
print(oddelovac)
print("Tohle je jednoduchy kod na slozeni tri vet dohromady.")
print(oddelovac)
veta1 = input("Zadej vetu jedna: ")
print(oddelovac)
veta2 = input("Zadej vetu dva: ")
print(oddelovac)
veta3 = input("Zadej vetu tri: ")
print(oddelovac)
vysledny_text = veta1 + " " + veta2 + " " + veta3
print(vysledny_text)
print(oddelovac)
# Out:
# ...
# Tohle je jednoduchy kod na slozeni tri vet dohromady.
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     618         """
# --> 619         parts = [self.recv(flags, copy=copy, track=track)]
# ...

# %%
print("=" * 100)

# %%
+, /, *, - #prace s cislama

# %% [markdown]
# #Zadej vetu a zjisti kolik ma znaku!

# %%
oddelovac = "=" * 80
print(oddelovac)
veta = input("Zadej vetu: ")
print(oddelovac)
print("Tvoje vete je dlouha celkem: ", len(veta), "znaku.")
# Out:
# ...
# Zadej vetu: Python je super
# ...
# Tvoje vete je dlouha celkem:  15 znaku.
